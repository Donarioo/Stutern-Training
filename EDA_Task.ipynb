# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
from plotnine import *

# %%
#importing dataset
dataset = pd.read_csv(r'Train.csv')
dataset.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
dataset.shape
# Out:
# (10999, 12)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
#Exploring the Numerical Data in the Dataset
dataset.describe()
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# ...

# %% [markdown]
# Data Eploration of the numerical data  in the dataset, shows that; the average number of calls put to the customer care is approximately 4.05 with a minimum of 1 and a maximum of 7. For customer rating, the average rating is 2.99 in a rating of scale 1-5, The average cost of producta is 210.19, while the average of prior purchases by individuals is 3.56, with minimum and maximum Prior purchases being 2 and 10 respectively. The average discount offered is 13.37 with the minimum beign 1.00 and the maximum discount offered being 65.00. Average weight in gram's of products equals 3634.01.

# %% [markdown]
# **Exploring Categorical Data in the Dataset**

# %%
sns.countplot(x='Warehouse_block',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Mode_of_Shipment',data=dataset)
# Out:
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='count'>

# %%
sns.countplot(x='Gender',data=dataset)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Product_importance',data=dataset)
# Out:
# <AxesSubplot:xlabel='Product_importance', ylabel='count'>

# %% [markdown]
# Exploration of Categorical data in the Dataset shows that there are five warehouses block. Four(A,B,C,& D) of the warehouse blocks have carried out almost the same amount of sale while the fifth (F) warehouse can be said to be an outlier with more sales than the others. The reason for more sales from the F warehouse can be related to various reason which we shall try to explore later in this EDA. Exploration of categorical data also shows ship to be the most use form of transport as against Flight and Road modes of transportation which has almost same number of deliveries. Exploration also shows a balance number of male and female customers in the dataset. And finally Product importance, which is seen through the above chart to have more of products with low importance

# %% [markdown]
# **Relationships Between Variables**

# %%
sns.heatmap(dataset.corr())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Warehouse_block',hue='Mode_of_Shipment',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Gender',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Product_importance',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Reached.on.Time_Y.N',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Customer_care_calls',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Customer_rating',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Warehouse_block',hue='Prior_purchases',data=dataset)
# Out:
# <AxesSubplot:xlabel='Warehouse_block', ylabel='count'>

# %%
sns.countplot(x='Mode_of_Shipment',hue='Reached.on.Time_Y.N',data=dataset)
# Out:
# <AxesSubplot:xlabel='Mode_of_Shipment', ylabel='count'>

# %%
sns.jointplot(x='Prior_purchases', y='Discount_offered', data=dataset)

# %%
sns.jointplot(x='Prior_purchases', y='Cost_of_the_Product', data=dataset)

# %%
sns.jointplot(x='Mode_of_Shipment', y='Weight_in_gms', data=dataset)

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# Exploratory Data Analysis(EDA) showed that variable in our dataset has very little or no correlation. Increase in sales in Warehouse Block F cannot be said to be attributed to other factors or variable from the dataset given. The reason for the high data or sale from Warehouse F might be due to many factors external to the Dataset for example; location of the Warehouse, size of the warehouse, and it might also be as a result of more data being collected from Warehouse F than the other warehouse. We saw that Ship is the most preferable mode of shippment/transportation however analysis showed that the mode of transportation is not really related to the weight of the product. Personally, I think this data is highly hypothetical and might not be the situation in a real world setting.
